# %%
import pylab, math, random
import numpy as np
import pandas as pd
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
from matplotlib.collections import LineCollection
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cmx
plt.style.use('ggplot')

# %% [markdown]
# **Stationary entropy**
#
# Stationary gaze entropy estimates uncertainty in overall spatial dispersion of fixations across a visual scene.

# %%
# generate simulation of fixations with pseudo-gaussian distribution for simplicity and calculate entropy
# to see how it varies with number of fixations, their distribution and number of discrete state spaces generated

random.seed(99999) #set seed for reproducibility

N = 500 #observed number of fixations (adjust as necessary)
minn = 900 #limit for gaussian - just to make ploting easier
maxn = 0 #limit for gaussian
mean = minn/2
sd = mean/3

#pseudo-gaussian distribution due to the minn maxn parameters set
x = [min(minn, max(maxn, random.gauss(mean, sd))) for i in range(N)]
y = [min(minn, max(maxn, random.gauss(mean, sd))) for i in range(N)]
xy = np.vstack((x,y))
s = minn #state spaces (maximum coordinate value)
sby = 80 #interval for state space division

#create dataframe with fixation coordinates and state spaces (i.e. x_range)
xydf=pd.DataFrame(xy.reshape(N,2), index = np.arange(N), columns=('x','y'))
xydf['x_range'] = pd.cut(xydf.x, np.arange(0, s, sby), right=False)
xydf['y_range'] = pd.cut(xydf.y, np.arange(0, s, sby), right=False)

#plot the coordinates and set grid limit according to the state spaces generated
plt.scatter(xydf.x, xydf.y, marker='x', c='red')
plt.axis([0, s, 0, s])
plt.xticks((np.arange(0, s, sby)))
plt.yticks((np.arange(0, s, sby)))

#generate probablity distributions for each state space to calculate entropy
xydf=xydf.groupby(['x_range','y_range']).size().reset_index().rename(columns={0:'count'})
xydf['p']=xydf['count']/xydf['count'].sum()

#multiply each p by its log
p_by_log = list()
for i in np.array(xydf['p']):
    p_by_log.append(math.log2(i)*i)
xydf['p*log(p)']= p_by_log

#list the number of state spaces, maximum entropy, observed entropy and normalised entropy
#NOTE: coordinates outside the defined state spaces are not included in the entropy calculation
print('State Spaces =',s/sby, '*', s/sby, '=', s/sby*s/sby)
print('Maximum H =' ,math.log2(s/sby*s/sby))
print('H =' ,abs(xydf['p*log(p)'].sum()))
print('Normalised H =' ,abs(xydf['p*log(p)'].sum()/math.log2(s/sby*s/sby)))
# Out:
# State Spaces = 11.25 * 11.25 = 126.5625
# Maximum H = 6.9837061926593496
# H = 5.777170430137165
# Normalised H = 0.8272356068200023

# %%
xydf=pd.DataFrame(xy.reshape(N,2), index = np.arange(N), columns=('x','y'))

xydf['x_from'] = xydf.x
xydf['y_from'] = xydf.y

xydf['x_to'] = xydf.x[1:].reset_index().x
xydf['y_to'] = xydf.y[1:].reset_index().y
xydf = xydf[:-1]

xydf['x_from_range'] = pd.cut(xydf.x_from, np.arange(0, s, sby), right=False)
xydf['y_from_range'] = pd.cut(xydf.y_from, np.arange(0, s, sby), right=False)
xydf['x_to_range'] = pd.cut(xydf.x_to, np.arange(0, s, sby), right=False)
xydf['y_to_range'] = pd.cut(xydf.y_to, np.arange(0, s, sby), right=False)

xydf['x_from_min'], xydf['x_from_max'] = (xydf['x_from_range'].apply(str).str.split(' ', 1).str)
xydf['x_to_min'], xydf['x_to_max'] = xydf['x_to_range'].apply(str).str.split(' ', 1).str

xydf['x_from_min']=xydf['x_from_min'].str.strip('[),').astype(float)
xydf['x_from_max']=xydf['x_from_max'].str.strip('[),').astype(float)
xydf['x_from']=(xydf['x_from_min']+ xydf['x_from_max'])/2

xydf['x_to_min']=xydf['x_to_min'].str.strip('[),').astype(float)
xydf['x_to_max']=xydf['x_to_max'].str.strip('[),').astype(float)
xydf['x_to']=(xydf['x_to_min']+xydf['x_to_max'])/2

xydf['y_from_min'], xydf['y_from_max'] = (xydf['y_from_range'].apply(str).str.split(' ', 1).str)
xydf['y_to_min'], xydf['y_to_max'] = xydf['y_to_range'].apply(str).str.split(' ', 1).str

xydf['y_from_min']=xydf['y_from_min'].str.strip('[),').astype(float)
xydf['y_from_max']=xydf['y_from_max'].str.strip('[),').astype(float)
xydf['y_from']=(xydf['y_from_min']+xydf['y_from_max'])/2

xydf['y_to_min']=xydf['y_to_min'].str.strip('[),').astype(float)
xydf['y_to_max']=xydf['y_to_max'].str.strip('[),').astype(float)
xydf['y_to']=(xydf['y_to_min']+xydf['y_to_max'])/2

xydf=xydf.groupby(['x_from','y_from','x_to','y_to']).size().reset_index().rename(columns={0:'count'})

#plot transitions
cmap = plt.cm.jet
cNorm  = colors.Normalize(vmin=np.min(xydf['count']), vmax=np.max(xydf['count']))

scalarMap = cmx.ScalarMappable(norm=cNorm,cmap=cmap)

fig = plt.figure()
ax  = fig.add_axes([0.1, 0.1, 0.7, 0.85]) 
axc = fig.add_axes([0.85, 0.10, 0.05, 0.85])

for index, row in xydf.iterrows():
    ax.axis([0, s, 0, s])
    colorVal = scalarMap.to_rgba(xydf.at[index,'count'])
    ax.arrow(xydf.at[index,'x_from'],  # x1
             xydf.at[index,'y_from'],  # y1
             xydf.at[index,'x_to']-xydf.at[index,'x_from'], # x2 - x1
             xydf.at[index,'y_to']-xydf.at[index,'y_from'], # y2 - y1
             color=colorVal,width=.5)


cb1 = mpl.colorbar.ColorbarBase(axc, cmap=cmap,
                                norm=cNorm,orientation='vertical')

plt.show()
